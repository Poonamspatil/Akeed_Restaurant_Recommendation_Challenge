# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans

# %%
train=pd.read_csv("train.csv")

# %%
train.head()
# Out:
#   akeed_customer_id gender  dob  status_x  verified_x language_x  \
# 0           TCHWPBT   Male  NaN         1           1         EN
# 1           TCHWPBT   Male  NaN         1           1         EN
# 2           ZGFSYCZ   Male  NaN         1           1         EN
# 3           ZGFSYCZ   Male  NaN         1           1         EN
# 4           ZGFSYCZ   Male  NaN         1           1         EN
#
#           created_at_x         updated_at_x  location_number location_type  \
# 0  2018-02-07 19:16:23  2018-02-07 19:16:23                0          Work
# 1  2018-02-07 19:16:23  2018-02-07 19:16:23                0          Work
# 2  2018-02-09 12:04:42  2018-02-09 12:04:41                0          Home
# 3  2018-02-09 12:04:42  2018-02-09 12:04:41                0          Home
# 4  2018-02-09 12:04:42  2018-02-09 12:04:41                0          Home
#
#    ...  open_close_flags            vendor_tag  \
# 0  ...               1.0  1,5,8,57,30,27,24,16
# ...

# %%
train.columns.values
# Out:
# array(['akeed_customer_id', 'gender', 'dob', 'status_x', 'verified_x',
#        'language_x', 'created_at_x', 'updated_at_x', 'location_number',
#        'location_type', 'latitude_x', 'longitude_x', 'akeed_order_id',
#        'customer_id', 'item_count', 'grand_total', 'payment_mode',
#        'promo_code', 'vendor_discount_amount',
#        'promo_code_discount_percentage', 'is_favorite', 'is_rated',
#        'vendor_rating_x', 'driver_rating', 'deliverydistance',
#        'preparationtime', 'delivery_time', 'order_accepted_time',
#        'driver_accepted_time', 'ready_for_pickup_time', 'picked_up_time',
#        'delivered_time', 'delivery_date', 'vendor_id', 'created_at_y',
#        'LOCATION_NUMBER', 'LOCATION_TYPE', 'CID X LOC_NUM X VENDOR',
#        'Target', 'id', 'authentication_id', 'latitude_y', 'longitude_y',
#        'vendor_category_en', 'vendor_category_id', 'delivery_charge',
#        'serving_distance', 'is_open', 'OpeningTime', 'OpeningTime2',
# ...

# %%
d = {"Feature":[i for i in train.columns]    ,"Nunique" :train.nunique().values ,'Type' : train.dtypes.values }
description = pd.DataFrame(data = d)
description
# Out:
#                            Feature  Nunique     Type
# 0                akeed_customer_id    34523   object
# 1                           gender       10   object
# 2                              dob       65  float64
# 3                         status_x        2    int64
# 4                       verified_x        2    int64
# 5                       language_x        1   object
# 6                  location_number        1    int64
# 7                    location_type        3   object
# 8                       latitude_x    34101  float64
# 9                      longitude_x    34145  float64
# 10                  akeed_order_id   131945  float64
# 11                      item_count       34  float64
# 12                     grand_total     1042  float64
# 13                    payment_mode        5  float64
# 14                      promo_code     1363   object
# 15          vendor_discount_amount       78  float64
# 16  promo_code_discount_percentage        4  float64
# ...

# %%
train.drop(['customer_id','created_at_x','updated_at_x','akeed_order_id'],axis=1,inplace=True)

# %%
train.shape
# Out:
# (139771, 95)

# %%
train['akeed_customer_id'].value_counts().head()
# Out:
# XW90EAP    262
# TL7Z2DM    151
# VDEJEMP    146
# HJFTTGW    128
# B28LJKM    119
# Name: akeed_customer_id, dtype: int64

# %% [markdown]
# ## DOB

# %%
print(train['dob'].notnull().sum())
print(train['dob'].isnull().sum())
# Out:
# 12511
# 127260

# %%
#train['dob']=train['dob'].astype(str)

# %%
#df.groupby('akeed_customer_id').ffill()

# %%
train['dob'] = train.groupby('akeed_customer_id')['dob'].fillna(method='ffill')

# %%
#train.groupby('akeed_customer_id')['dob'].fillna(method='bfill')

# %%
train.groupby('akeed_customer_id')['dob'].apply(lambda x: x.fillna(method='ffill')).head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: dob, dtype: float64

# %%
#train.groupby('akeed_customer_id')['dob'].ffill()

# %%
train['dob'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: dob, dtype: float64

# %%
train['dob'].isnull().sum()
# Out:
# 127260

# %%
train.head()
# Out:
#   akeed_customer_id gender  dob  status_x  verified_x language_x  \
# 0           TCHWPBT   Male  NaN         1           1         EN
# 1           TCHWPBT   Male  NaN         1           1         EN
# 2           ZGFSYCZ   Male  NaN         1           1         EN
# 3           ZGFSYCZ   Male  NaN         1           1         EN
# 4           ZGFSYCZ   Male  NaN         1           1         EN
#
#           created_at_x         updated_at_x  location_number location_type  \
# 0  2018-02-07 19:16:23  2018-02-07 19:16:23                0          Work
# 1  2018-02-07 19:16:23  2018-02-07 19:16:23                0          Work
# 2  2018-02-09 12:04:42  2018-02-09 12:04:41                0          Home
# 3  2018-02-09 12:04:42  2018-02-09 12:04:41                0          Home
# 4  2018-02-09 12:04:42  2018-02-09 12:04:41                0          Home
#
#    ...  open_close_flags            vendor_tag  \
# 0  ...               1.0  1,5,8,57,30,27,24,16
# ...

# %%
X=train.copy()
del X['Target']
y=train

# %% [markdown]
# ## Gender

# %%
train['gender'].unique()
# Out:
# array(['Male', 'Female', 'Female  ', 'Female   ', 'Female    ', 'Male  ',
#        '  ', 'Female ', nan, '?????', 'male'], dtype=object)

# %%
train['gender']=train['gender'].astype(str)

# %%
def gender(title):
    if title=='Male' or title=='Male  ' or title=='male' :
        return 'male'
    elif title=='Female'  or title=='Female  '  or title=='Female   ' or title=='Female    ' or title='Female ':
        return 'female'
    else:
        return 'na'

# %%
train['gender']=train['gender'].apply(gender)

# %%
train['gender'].unique()
# Out:
# array(['male', 'female', 'na'], dtype=object)

# %% [markdown]
# ## Lat & Long

# %%
train[[ 'latitude_x', 'longitude_x']].isnull().sum()
# Out:
# latitude_x     4
# longitude_x    4
# dtype: int64

# %%
train[[ 'latitude_x', 'longitude_x']]=train[[ 'latitude_x', 'longitude_x']].dropna()

# %%
## Reduce memory usage
def reduce_mem_usage(df, verbose=True):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage().sum() / 1024**2    
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)    
    end_mem = df.memory_usage().sum() / 1024**2
    if verbose: print('Mem. usage decreased to {:5.2f} Mb ({:.1f}% reduction)'.format(end_mem, 100 * (start_mem - end_mem) / start_mem))
    return df

# %%
train=reduce_mem_usage(train)
# Out:
# Mem. usage decreased to 69.45 Mb (30.0% reduction)

# %%
#cluster lat and long
kmeans=KMeans(n_clusters=5,init='k-means++')
kmeans.fit(train[[ 'latitude_x', 'longitude_x']])
train['cluster_label'] = kmeans.fit_predict(train[[ 'latitude_x', 'longitude_x']])
centers = kmeans.cluster_centers_ # Coordinates of cluster centers.
labels = kmeans.predict(train[[ 'latitude_x', 'longitude_x']])
# Full_data['cluster_label'].value_counts()
train.plot.scatter(x = 'latitude_x', y = 'longitude_x', c=labels, s=50, cmap='viridis')
plt.scatter(centers[:, 0], centers[:, 1], c='r', s=200, alpha=0.5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-97-2c3ebb858f4e> in <module>
#       1 #cluster lat and long
#       2 kmeans=KMeans(n_clusters=5,init='k-means++')
# ----> 3 kmeans.fit(train[[ 'latitude_x', 'longitude_x']])
#       4 train['cluster_label'] = kmeans.fit_predict(train[[ 'latitude_x', 'longitude_x']])
#       5 centers = kmeans.cluster_centers_ # Coordinates of cluster centers.
#
# ~\Downloads\ANACONDA\lib\site-packages\sklearn\cluster\k_means_.py in fit(self, X, y, sample_weight)
#     969                 tol=self.tol, random_state=random_state, copy_x=self.copy_x,
#     970                 n_jobs=self.n_jobs, algorithm=self.algorithm,
# --> 971                 return_n_iter=True)
#     972         return self
#     973
#
# ...

# %% [markdown]
# ## vendor_tag_name

# %%
train['vendor_tag_name']=train['vendor_tag_name'].astype(str)

# %%
train['vendor_tag_name']=train['vendor_tag_name'].apply(lambda x: x.split(','))

# %%
train['vendor_tag_name'].head()
# Out:
# 0    [American, Burgers, Desserts, Donuts, Fries, P...
# 1            [Arabic, Desserts, Free Delivery, Indian]
# 2    [Coffee, Fresh Juices, Hot Chocolate, Sandwich...
# 3    [Coffee, Fresh Juices, Hot Chocolate, Sandwich...
# 4    [Coffee, Fresh Juices, Hot Chocolate, Sandwich...
# Name: vendor_tag_name, dtype: object

# %%
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
from nltk.corpus import stopwords
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-107-804b9edfa4c3> in <module>
#       1
# ----> 2 from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
#       3 from nltk.corpus import stopwords
#
# ModuleNotFoundError: No module named 'wordcloud'

# %%
wc= WordCloud(background_color="white", random_state=1,stopwords=STOPWORDS, max_words = 2000, width =800, height = 1500)
wc.generate(train['vendor_tag_name'])

plt.figure(figsize=[10,10])
plt.imshow(wc,interpolation="bilinear")
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-105-069bd1903d80> in <module>
# ----> 1 wc= WordCloud(background_color="white", random_state=1,stopwords=STOPWORDS, max_words = 2000, width =800, height = 1500)
#       2 wc.generate(train['vendor_tag_name'])
#       3
#       4 plt.figure(figsize=[10,10])
#       5 plt.imshow(wc,interpolation="bilinear")
#
# NameError: name 'WordCloud' is not defined
